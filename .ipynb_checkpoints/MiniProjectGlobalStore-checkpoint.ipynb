# %% [markdown]
# # MINI PROJECT
#
# ## SuperStore

# %% [markdown]
# measured in dollar

# %%
#importing libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as pl
import seaborn as sns
#another recent discovered library
import plotly.express as px

#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

#slight tweaking for the visualisation
plt.style.use("ggplot")

# %%
df = pd.read_csv("superstore.csv")

# %%
data = df.copy()

# %%
data.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order.Date        Order.ID  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969
#
#   Order.Priority       Product.ID  \
# 0           High  OFF-PA-10002005
# 1         Medium  OFF-PA-10002893
# ...

# %%
data.shape
# Out:
# (51290, 27)

# %% [markdown]
# ## **Data Cleaning & Preprocessing**

# %%
missing = data.isnull().sum().sort_values(ascending=False)

missing
# Out:
# Category          0
# Quantity          0
# Market2           0
# Year              0
# Sub.Category      0
# State             0
# Shipping.Cost     0
# Ship.Mode         0
# Ship.Date         0
# Segment           0
# Sales             0
# Row.ID            0
# Region            0
# Profit            0
# City              0
# Product.Name      0
# Product.ID        0
# Order.Priority    0
# Order.ID          0
# Order.Date        0
# 记录数               0
# Market            0
# Discount          0
# Customer.Name     0
# Customer.ID       0
# Country           0
# weeknum           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.nunique().sort_values()
# Out:
# 记录数                   1
# Category              3
# Segment               3
# Year                  4
# Ship.Mode             4
# Order.Priority        4
# Market2               6
# Market                7
# Region               13
# Quantity             14
# Sub.Category         17
# Discount             27
# weeknum              53
# Country             147
# Customer.Name       795
# State              1094
# Order.Date         1430
# Ship.Date          1464
# Sales              2246
# City               3636
# Product.Name       3788
# Customer.ID        4873
# Product.ID        10292
# Shipping.Cost     16877
# Profit            24575
# Order.ID          25035
# Row.ID            51290
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
#view datatypes
data.dtypes
# Out:
# Category           object
# City               object
# Country            object
# Customer.ID        object
# Customer.Name      object
# Discount          float64
# Market             object
# 记录数                 int64
# Order.Date         object
# Order.ID           object
# Order.Priority     object
# Product.ID         object
# Product.Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row.ID              int64
# Sales               int64
# Segment            object
# Ship.Date          object
# Ship.Mode          object
# Shipping.Cost     float64
# State              object
# Sub.Category       object
# Year                int64
# Market2            object
# weeknum             int64
# dtype: object

# %%
#To Print numerical columns
num_cols = data.select_dtypes(include=np.number).columns

num_cols
# Out:
# Index(['Discount', 'Profit', 'Quantity', 'Row.ID', 'Sales', 'Shipping.Cost',
#        'Year', 'weeknum'],
#       dtype='object')

# %%
data = data.drop(columns=['记录数'])

# %%
num_cols = data.select_dtypes(include=np.number).columns

num_cols
# Out:
# Index(['Discount', 'Profit', 'Quantity', 'Row.ID', 'Sales', 'Shipping.Cost',
#        'Year', 'weeknum'],
#       dtype='object')

# %%
#To print Categorical columns
cat_cols = data.select_dtypes(include="object").columns

cat_cols
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name', 'Market',
#        'Order.Date', 'Order.ID', 'Order.Priority', 'Product.ID',
#        'Product.Name', 'Region', 'Segment', 'Ship.Date', 'Ship.Mode', 'State',
#        'Sub.Category', 'Market2'],
#       dtype='object')

# %%
data.tail()
# Out:
#               Category         City        Country Customer.ID  \
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#         Customer.Name  Discount Market               Order.Date  \
# 51285  Alice McCarthy       0.2     US  2014-12-03 00:00:00.000
# 51286  Alice McCarthy       0.2     US  2014-12-03 00:00:00.000
# 51287  Hallie Redmond       0.2     US  2014-12-18 00:00:00.000
# 51288   Robert Marley       0.2     US  2014-12-25 00:00:00.000
# 51289    Fred Hopkins       0.2     US  2014-12-26 00:00:00.000
#
#              Order.ID Order.Priority       Product.ID  \
# 51285  CA-2014-109701           High  OFF-BI-10000632
# 51286  CA-2014-109701           High  OFF-BI-10004187
# ...

# %%
data["Order.ID"].duplicated().sum()
# Out:
# np.int64(26255)

# %%
#Setting up the date fromat correct

data['Order Date'] = pd.to_datetime(data['Order.Date'])

data['Ship Date'] = pd.to_datetime(data['Ship.Date'])

# %%
#Checking range of date

print(data['Order Date'].min())
print(data['Order Date'].max())
# Out:
# 2011-01-01 00:00:00
# 2014-12-31 00:00:00

# %%
#CHecking the years of trade

data['Order Date'].dt.year.unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int32)

# %%
#Checking the total distribution betweeen countries

data['Country'].value_counts()
# Out:
# Country
# United States                       9994
# Australia                           2837
# France                              2827
# Mexico                              2644
# Germany                             2065
# China                               1880
# United Kingdom                      1633
# Brazil                              1599
# India                               1555
# Indonesia                           1390
# Turkey                              1378
# Italy                               1108
# Nigeria                              905
# Spain                                859
# Dominican Republic                   742
# El Salvador                          736
# Cuba                                 724
# Honduras                             713
# Philippines                          681
# New Zealand                          628
# Nicaragua                            614
# Iran                                 607
# Guatemala                            521
# ...

# %%
#Region Distribtion

data['Region'].value_counts()
# Out:
# Region
# Central           11117
# South              6645
# EMEA               5029
# North              4785
# Africa             4587
# Oceania            3487
# West               3203
# Southeast Asia     3129
# East               2848
# North Asia         2338
# Central Asia       2048
# Caribbean          1690
# Canada              384
# Name: count, dtype: int64

# %%
#Category Distribution

data['Category'].value_counts()
# Out:
# Category
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: count, dtype: int64

# %%
data['Ship.Mode'].value_counts()
# Out:
# Ship.Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64

# %%
data.corr(numeric_only=True)
# Out:
#                Discount    Profit  Quantity    Row.ID     Sales  \
# Discount       1.000000 -0.316490 -0.019875  0.087594 -0.086728
# Profit        -0.316490  1.000000  0.104365 -0.019037  0.484923
# Quantity      -0.019875  0.104365  1.000000 -0.173483  0.313580
# Row.ID         0.087594 -0.019037 -0.173483  1.000000 -0.043888
# Sales         -0.086728  0.484923  0.313580 -0.043888  1.000000
# Shipping.Cost -0.079055  0.354441  0.272649 -0.039076  0.768075
# Year          -0.005894  0.002626 -0.005049 -0.000921 -0.002902
# weeknum       -0.000217 -0.000182  0.020839 -0.028776  0.001947
#
#                Shipping.Cost      Year   weeknum
# Discount           -0.079055 -0.005894 -0.000217
# Profit              0.354441  0.002626 -0.000182
# Quantity            0.272649 -0.005049  0.020839
# Row.ID             -0.039076 -0.000921 -0.028776
# Sales               0.768075 -0.002902  0.001947
# Shipping.Cost       1.000000 -0.003137  0.005347
# ...

# %%
plt.figure(figsize=(10,6))

sns.heatmap(
    data.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)

plt.show()

# %%
#Finding Outliers

import matplotlib.pyplot as plt

numeric = data.select_dtypes(include=np.number)

for column in numeric.columns:
#displays the outliers for each column, in that way we can understand the value distribution.
    plt.figure(figsize=(8,3))

    plt.boxplot(data[column],vert=False)

    plt.title(column)

    plt.show()

# %%
data.describe().T
# Out:
#                  count                           mean                  min  \
# Discount       51290.0                       0.142908                  0.0
# Profit         51290.0                      28.610982            -6599.978
# Quantity       51290.0                       3.476545                  1.0
# Row.ID         51290.0                        25645.5                  1.0
# Sales          51290.0                      246.49844                  0.0
# Shipping.Cost  51290.0                      26.375818                0.002
# Year           51290.0                    2012.777208               2011.0
# weeknum        51290.0                      31.287112                  1.0
# Order Date       51290  2013-05-11 21:26:49.155780864  2011-01-01 00:00:00
# Ship Date        51290  2013-05-15 20:42:42.745174784  2011-01-03 00:00:00
#
#                                25%                  50%                  75%  \
# ...

# %% [markdown]
# **Data Quality Report**
#
#
# Check	           Result
# Missing Values	     0
# Duplicate Rows	     0
# Numeric Columns	     8
# Categorical Columns	 18
# Dataset Size	     51290 rows, 26 columns(*1 column dropped)
#
# **Brief;**
#
# The Global Superstore dataset contains transactional sales records across multiple countries, product categories, customer segments, and shipping modes.Each record represents an individual order with details about sales, profit, discount, quantity, customer, and geography. This dataset enables analysis of sales performance, customer behavior, product profitability, regional trends, and operational efficiency.
#
# **Observations**
#
#  - Dataset contains 51290 rows and 27 columns. removed 1 column.
#  - Covers transactions from 2011–2014.
#  - Contains 8 numerical and 18 categorical features.
#  - None missing or duplicate records identified:
#  - Date columns were converted to datetime format.
#  - Dataset is suitable for business analytics, feature engineering, predictive modeling, and dashboard development.

# %% [markdown]
# ## **Exploratory Data Analysis**
#
# ## SALES ANALYSIS
#
# **Total sales**

# %%
total_sales = data['Sales'].sum()

print(f"Total Sales : ${total_sales:,.2f}")
# Out:
# Total Sales : $12,642,905.00

# %% [markdown]
# **Total Profit**

# %%
total_profit = data['Profit'].sum()

print(f"Total Profit : ${total_profit:,.2f}")
# Out:
# Total Profit : $1,467,457.29

# %%
#Finding the Profit Margin in percentage

profit_margin = (
    total_profit /
    total_sales
) * 100

print(f"{profit_margin:.2f}%")
# Out:
# 11.61%

# %% [markdown]
# **Total Orders**

# %%
print( "Total orders: ", data['Order.ID'].nunique())
# Out:
# Total orders:  25035

# %% [markdown]
# **To find TOTAL NUMBER OF EXISTING UNIQUE CUSTOMERS**

# %%
print( "Total Customers: ", data['Customer.ID'].nunique())
# Out:
# Total Customers:  4873

# %% [markdown]
# **Average Order value**

# %%
aov = total_sales / data['Order.ID'].nunique()

print("Average order value: $",aov)
# Out:
# Average order value: $ 505.0091871380068

# %% [markdown]
# **Average Profit per Order**

# %%
print("Average Profit per Order: $", total_profit / data['Order.ID'].nunique())
# Out:
# Average Profit per Order: $ 58.616228930697034

# %% [markdown]
# **Total Products Sold**

# %%
print("Total Products Sold:", data['Quantity'].sum(), 'NOS')
# Out:
# Total Products Sold: 178312 NOS

# %% [markdown]
# **Total sales by Category**

# %%
sales_category = data.groupby(
    'Category'
)['Sales'].sum().sort_values()

sales_category
# Out:
# Category
# Office Supplies    3787330
# Furniture          4110884
# Technology         4744691
# Name: Sales, dtype: int64

# %%
#visualization

sales_category.plot(
    kind='bar',
    figsize=(8,4),
    color='royalblue'
)

plt.title("Sales by Category")

plt.show()

# %%
#there's also sub-categories

sales_sub = (
    data.groupby(
        'Sub.Category'
    )['Sales']
    .sum()
    .sort_values()
)

sales_sub
# Out:
# Sub.Category
# Labels           73433
# Fasteners        83254
# Envelopes       170926
# Supplies        243090
# Paper           244307
# Art             372163
# Furnishings     385609
# Binders         461952
# Accessories     749307
# Tables          757034
# Machines        779071
# Appliances     1011081
# Storage        1127124
# Bookcases      1466559
# Chairs         1501682
# Copiers        1509439
# Phones         1706874
# Name: Sales, dtype: int64

# %%
sales_sub.plot(
    kind='barh',
    figsize=(8,4),
    color='royalblue'
)

plt.title("Sales by Sub-Category")
plt.xlabel("Sales Volume", fontsize=12, labelpad=20)
plt.ylabel("Sub-Category", fontsize=12, labelpad=20)

tick_values = range(0, 1800001, 100000) 
plt.xticks(tick_values)

plt.show()

# %% [markdown]
# **Top 20 Products**

# %%
top20 = (
    data.groupby(
        'Product.Name'
    )['Sales']
    .sum()
    .sort_values(
        ascending=False
    )
    .head(20)
)

top20
# Out:
# Product.Name
# Apple Smart Phone, Full Size                                86936
# Cisco Smart Phone, Full Size                                76441
# Motorola Smart Phone, Full Size                             73159
# Nokia Smart Phone, Full Size                                71904
# Canon imageCLASS 2200 Advanced Copier                       61600
# Hon Executive Leather Armchair, Adjustable                  58200
# Office Star Executive Leather Armchair, Adjustable          50667
# Harbour Creations Executive Leather Armchair, Adjustable    50120
# Samsung Smart Phone, Cordless                               48654
# Nokia Smart Phone, with Caller ID                           47880
# Samsung Smart Phone, VoIP                                   45406
# Cisco Smart Phone, with Caller ID                           43124
# SAFCO Executive Leather Armchair, Black                     41921
# Cisco Smart Phone, Cordless                                 41021
# ...

# %% [markdown]
# **sale by segment**

# %%
plt.figure(figsize=(6,6))

data.groupby('Segment')['Sales'].sum().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.ylabel("")
plt.show()

# %%
region = data.groupby(
    'Region'
)['Sales'].sum()

region
# Out:
# Region
# Africa             783776
# Canada              66932
# Caribbean          324281
# Central           2822399
# Central Asia       752839
# EMEA               806184
# East               678834
# North             1248192
# North Asia         848349
# Oceania           1100207
# South             1600960
# Southeast Asia     884438
# West               725514
# Name: Sales, dtype: int64

# %%
state_sales = data.groupby(
    'Country'
)['Sales'].sum()

state_sales
# Out:
# Country
# Afghanistan                           21674
# Albania                                3888
# Algeria                               36090
# Angola                                25551
# Argentina                             57510
# Armenia                                 156
# Australia                            925257
# Austria                               92543
# Azerbaijan                             5630
# Bahrain                                 669
# Bangladesh                            78254
# Barbados                               7175
# Belarus                               13390
# Belgium                               49233
# Benin                                  6215
# Bolivia                               11589
# Bosnia and Herzegovina                 2600
# Brazil                               361098
# Bulgaria                              15560
# Burundi                                 268
# Cambodia                              17476
# ...

# %% [markdown]
# **Monthly sales trend**

# %%
monthly = data.groupby('Month')['Sales'].sum()

monthly.plot(
    marker='o',
    figsize=(12,5)
)

plt.ylabel("Sales")

plt.show()

# %% [markdown]
# **Yearly sales Trend**

# %%
year = data.groupby('Year')['Sales'].sum()

year.plot(
    marker='o',
    figsize=(8,4)
)

plt.show()

# %% [markdown]
# **Top 10 Customers**

# %%
print( "Total Customers: ", data['Customer.ID'].nunique())
# Out:
# Total Customers:  4873

# %%
top_customer = data.groupby(
    'Customer.Name'
)['Sales'].sum().nlargest(10)

top_customer.plot(kind='bar')

plt.show()

# %% [markdown]
# **Discount vs Profit**

# %%
sns.scatterplot(
    data=data,
    x='Discount',
    y='Profit'
)

plt.show()

# %% [markdown]
# **Sales vs Profit**

# %%
sns.scatterplot(
    data=data,
    x='Sales',
    y='Profit'
)

plt.show()

# %% [markdown]
# ## Summary
#
# • Technology category generated the highest sales and profit.
#
# • Consumer segment contributed the largest share of revenue.
#
# • Sales increased over the years, indicating business growth.
#
# • Monthly sales showed seasonal fluctuations.
#
# • A small number of products generated a major portion of revenue.
#
# • Some transactions resulted in negative profit despite high sales.
#
#
# • The analysis suggests optimizing discount strategies, focusing on profitable product categories, strengthening customer retention programs, and improving inventory planning to maximize long-term profitability.

# %% [markdown]
# **Statistical Analysis**

# %%
import pandas as pd
import numpy as np

from scipy.stats import ttest_ind
from scipy.stats import chi2_contingency

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.describe()
# Out:
#            Discount        Profit      Quantity       Row.ID         Sales  \
# count  51290.000000  51290.000000  51290.000000  51290.00000  51290.000000
# mean       0.142908     28.610982      3.476545  25645.50000    246.498440
# min        0.000000  -6599.978000      1.000000      1.00000      0.000000
# 25%        0.000000      0.000000      2.000000  12823.25000     31.000000
# 50%        0.000000      9.240000      3.000000  25645.50000     85.000000
# 75%        0.200000     36.810000      5.000000  38467.75000    251.000000
# max        0.850000   8399.976000     14.000000  51290.00000  22638.000000
# std        0.212280    174.340972      2.278766  14806.29199    487.567175
#
#        Shipping.Cost          Year       weeknum  \
# count   51290.000000  51290.000000  51290.000000
# mean       26.375818   2012.777208     31.287112
# min         0.002000   2011.000000      1.000000
# 25%         2.610000   2012.000000     20.000000
# ...

# %%
#Correlation Analysis

corr = data[['Sales','Profit','Quantity','Discount','Shipping.Cost']].corr()

corr
# Out:
#                   Sales    Profit  Quantity  Discount  Shipping.Cost
# Sales          1.000000  0.484923  0.313580 -0.086728       0.768075
# Profit         0.484923  1.000000  0.104365 -0.316490       0.354441
# Quantity       0.313580  0.104365  1.000000 -0.019875       0.272649
# Discount      -0.086728 -0.316490 -0.019875  1.000000      -0.079055
# Shipping.Cost  0.768075  0.354441  0.272649 -0.079055       1.000000

# %%
plt.figure(figsize=(8,5))

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)

plt.show()

# %% [markdown]
# **T-test**

# %%
consumer = data[
    data['Segment']=="Consumer"
]['Profit']

corporate = data[
    data['Segment']=="Corporate"
]['Profit']

t,p = ttest_ind(
    consumer,
    corporate,
    equal_var=False
)

print(t)
print(p)
# Out:
# -0.19192651562608662
# 0.847800993188607

# %% [markdown]
# p>0.05
#
# fail to reject the null hypothesis. There is no evidence of a difference in mean Profit between the Consumer and Corporate segments.

# %% [markdown]
# **Chi-Square Test**

# %%
table = pd.crosstab(
    data['Ship.Mode'],
    data['Segment']
)

chi,p,dof,expected = chi2_contingency(table)

print(chi)
print(p)
# Out:
# 18.274424263215174
# 0.005581770901920857

# %% [markdown]
# p<0.05
#
# Shipping mode selection is significantly associated with customer segment.

# %% [markdown]
# **Box Plot Analysed through box plot**

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=data,
    x='Category',
    y='Profit'
)

plt.show()

# %% [markdown]
# **violin Plot Analysed through box plot**

# %%
plt.figure(figsize=(8,5))

sns.violinplot(
    data=data,
    x='Category',
    y='Sales'
)

plt.show()

# %% [markdown]
# **Statistical Findings**
#
# • Sales and Profit exhibit a positive correlation.
#
# • Discount negatively impacts Profit.
#
# • Sales are not normally distributed.
#
# • Profit varies significantly across product categories.
#
# • Shipping mode selection is associated with customer segment.
#
# • Statistical testing confirms that several observed business patterns are significant and not due to random variation.

# %% [markdown]
# ## **ML Analysis**
#
# Retail companies process thousands of orders daily. Predicting the expected profit of an order before fulfillment helps management optimize pricing, discounts, inventory planning, and operational decisions. Through developing predictive machine learning tools identifying the best scenarios
#
# Target Variable:
# Profit

# %%
#impporting Libraries

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   Order.Date      51290 non-null  object
#  8   Order.ID        51290 non-null  object
#  9   Order.Priority  51290 non-null  object
#  10  Product.ID      51290 non-null  object
#  11  Product.Name    51290 non-null  object
#  12  Profit          51290 non-null  float64
#  13  Quantity        51290 non-null  int64
#  14  Region          51290 non-null  object
#  15  Row.ID          51290 non-null  int64
#  16  Sales           51290 non-null  int64
# ...

# %%
#Dropping unneccessary columns

drop_columns = [

'Row.ID',
'Order.ID',
'Customer.ID',
'Customer.Name',
'Product.ID',
'Product.Name',
'Order.Date',
'Ship.Date'

]

data.drop(
    columns=drop_columns,
    inplace=True,
)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Discount        51290 non-null  float64
#  4   Market          51290 non-null  object
#  5   Order.Priority  51290 non-null  object
#  6   Profit          51290 non-null  float64
#  7   Quantity        51290 non-null  int64
#  8   Region          51290 non-null  object
#  9   Sales           51290 non-null  int64
#  10  Segment         51290 non-null  object
#  11  Ship.Mode       51290 non-null  object
#  12  Shipping.Cost   51290 non-null  float64
#  13  State           51290 non-null  object
#  14  Sub.Category    51290 non-null  object
#  15  Year            51290 non-null  int64
#  16  Market2         51290 non-null  object
# ...

# %%
data.dtypes
# Out:
# Category             object
# City                 object
# Country              object
# Discount            float64
# Market               object
# Order.Priority       object
# Profit              float64
# Quantity              int64
# Region               object
# Sales                 int64
# Segment              object
# Ship.Mode            object
# Shipping.Cost       float64
# State                object
# Sub.Category         object
# Year                  int64
# Market2              object
# weeknum               int64
# Month             period[M]
# dtype: object

# %%
#Encode Categorical Variables

#LabelEncoder

le = LabelEncoder()

# Include object, category, and period dtypes
target_cols = data.select_dtypes(include=['object', 'period[M]']).columns

for col in target_cols:
    data[col] = le.fit_transform(data[col].astype(str))

# %%
data.dtypes
# Out:
# Category            int64
# City                int64
# Country             int64
# Discount          float64
# Market              int64
# Order.Priority      int64
# Profit            float64
# Quantity            int64
# Region              int64
# Sales               int64
# Segment             int64
# Ship.Mode           int64
# Shipping.Cost     float64
# State               int64
# Sub.Category        int64
# Year                int64
# Market2             int64
# weeknum             int64
# Month               int64
# dtype: object

# %%
#Define Featrues and Targert

X = data.drop("Profit", axis=1)

y = data["Profit"]

# %%
#Train-Test Split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %% [markdown]
# **Linearregression**

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)

pred_lr = lr.predict(X_test)

# %%
#Evaluation

print("MAE :", mean_absolute_error(y_test,pred_lr))
print("RMSE :", np.sqrt(mean_squared_error(y_test,pred_lr)))
print("R2 :", r2_score(y_test,pred_lr))
# Out:
# MAE : 59.948997790625164
# RMSE : 159.79031329024062
# R2 : 0.13098337222747236

# %% [markdown]
# **Decision Tree**

# %%
dt = DecisionTreeRegressor(random_state=42)

dt.fit(X_train,y_train)

pred_dt = dt.predict(X_test)

# %%
#Evaluation

print("MAE :", mean_absolute_error(y_test,pred_dt))
print("RMSE :", np.sqrt(mean_squared_error(y_test,pred_dt)))
print("R2 :", r2_score(y_test,pred_dt))
# Out:
# MAE : 46.20529189510626
# RMSE : 128.5848715488242
# R2 : 0.4372610958089409

# %% [markdown]
# **Random Forest**

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

rf.fit(X_train,y_train)

pred_rf = rf.predict(X_test)

# %%
print("MAE :", mean_absolute_error(y_test,pred_rf))
print("RMSE :", np.sqrt(mean_squared_error(y_test,pred_rf)))
print("R2 :", r2_score(y_test,pred_rf))
